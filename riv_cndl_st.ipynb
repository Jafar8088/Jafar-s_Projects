# %% [markdown]
# # Conditional statements

# %% [markdown]
# ## if
# ## if else
# ## if elif

# %%
# if
a = int(input('Enter the number :'))
if a%2==0:
    print('Given number is even')
# Out:
# Enter the number : 7

# %%
# if else
#print the given number is odd or even
a = int(input('Enter the Number :'))
if a%2==0:
    print(a,'is even number')
else:
    print(a,'is odd number')
# Out:
# Enter the Number : 7
# 7 is odd number

# %%
#if elif else
per = int(input('Enter the value :'))
if per >= 60:
    print('First Division')
elif  per >= 50:
    print('Second Division')
elif per >= 35:
    print('Third division')
else:
    print('Fail')
# Out:
# Enter the value : 30
# Fail

# %% [markdown]
# # age 3->17 school age 18 to 28 college job

# %%
age = int(input('Enter the Age :'))
if age >= 0 and age <= 2:
    print('Eat, Play and Goto Sleep')
elif age >= 3 and age <= 17:
    print('Goto School')
elif age >= 18 and age <= 28:
    print('Goto college')
else:
    print(' Goto Job')
# Out:
# Enter the Age : 45
#  Goto Job

# %% [markdown]
# # if the temperature in between 30 to 50 print 'hot'
# # if the temperature in between 10 to 29 then print 'moderate'
# # if the temperature in between 1 to 9 print cool
# # if temperature less then one write don't go anywhere

# %%
temp = int(input('Enter the Tenperature value :'))
if temp >= 30 and Temp <= 50:
    print('Hot')
elif temp >= 10 and temp <= 29:
    print('"moderate')
elif temp >= 1 and temp <= 9:
    print('Cool')
else:
    print('Donot go any where')
# Out:
# Enter the Tenperature value : -1
# Donot go any where

# %% [markdown]
# # Bulit Simple Calculator using if elif else Statement

# %%
print('''
+ Addition
- Subtract
* Multiplication
/ Division
''')
num1 = int(input('Enter the First Number :'))
num2 = int(input('Enter the Second Number :'))
opr = input('Enter the Operator :')
if opr == '+':
    print(num1 + num2)
elif opr == '-':
    print(num1 - num2)
elif opr == '*':
    print(num1 * num2)
elif opr == '/':
    print(num1 / num2)
else:
    print('Invali Operations.......!!!!!!')
# Out:
# + Addition
# - Subtract
# * Multiplication
# / Division
# Enter the First Number : 5
# Enter the Second Number : 5
# Enter the Operator : =
# Invali Operations.......!!!!!!

# %% [markdown]
# # Bulit Simple Calculator using if Statement

# %%
print('''
+ Addition
- Subtraction
* Multiplication
/ Division
''')
num1 = int(input('Enter the First Number :'))
num2 = int(input('Enter the Second Number :'))
opr = input("Enter the Operator")
if opr == '+':
    print(num1 + num2)
if opr == '-':
    print(num1 - num2)
if opr == '*':
    print(num1 * num2)
if opr == '/':
    print(num1 / num2)
if opr != '+' and opr != '-' and opr != '*' and opr != '/':
    print('Invalid Opeartions!!!!!!')
# Out:
# + Addition
# - Subtraction
# * Multiplication
# / Division
# Enter the First Number : 10
# Enter the Second Number : 50
# Enter the Operator \
# Invalid Opeartions!!!!!!
